# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 0.05, 0.10, 0.15, 0.20, 0.25, 0.30 ])
ypoints = np.array([76.13, 66.85, 53.82, 23.62, 5.32, 0.86,  0.31])

plt.xlabel("Channel prune amount (%)")
plt.ylabel("Top-1 accuracy (%)")
plt.title("Validation accuracy on the resnet-50 model, fully-connected and convolutional layers pruned.")
plt.grid(axis = 'y')
plt.plot(xpoints, ypoints, marker = 'o', label='Linear + Conv2d layers pruned', color='blue')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 0.05, 0.10, 0.15, 0.20, 0.25, 0.30 ])
ypoints = np.array([76.13, 69.92, 59.05, 26.96, 6.39, 0.98,  0.34])

plt.xlabel("Channel prune amount (%)")
plt.ylabel("Top-1 accuracy (%)")
plt.title("Validation accuracy on the resnet-50 model, only convolutional layers pruned.")
plt.grid(axis = 'y')
plt.plot(xpoints, ypoints, marker = 's', label='Conv2d layers only pruned', color='green')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

linear_xpoints = np.array([0, 0.05, 0.10, 0.15, 0.20, 0.25, 0.30 ])
linear_ypoints = np.array([76.13, 66.85, 53.82, 23.62, 5.32, 0.86,  0.31])

xpoints = np.array([0, 0.05, 0.10, 0.15, 0.20, 0.25, 0.30 ])
ypoints = np.array([76.13, 69.92, 59.05, 26.96, 6.39, 0.98,  0.34])

plt.xlabel("Channel prune amount (%)")
plt.ylabel("Top-1 accuracy (%)")
plt.title("Validation accuracy on the resnet-50 model.")
plt.grid(axis = 'y')


plt.plot(linear_xpoints, linear_ypoints, marker = 'o', label='Linear + Conv2d layers pruned', color='blue')
plt.plot(xpoints, ypoints, marker = 's', label='Conv2d layers only pruned', color='green')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpruned = np.array([0, 0.0625, 0.125, 0.1875, 0.25, 0.50 ])
ypruned = np.array([69.75, 30.405, 5.702, 1.671,  0.391,  0.164])

xtuned = np.array([0, 0.0625, 0.125, 0.25])
ytuned = np.array([69.75, 53.719, 39.065, 12.522])

plt.xlabel("Channel prune amount (%)")
plt.ylabel("Top-1 accuracy (%)")
plt.title("Validation accuracy on the resnet-50 model, only convolutional layers pruned.")
plt.grid(axis = 'y')
plt.plot(xpruned, ypruned, marker = 's', label='pruned', color='red',linewidth=3)
plt.plot(xtuned, ytuned, marker = 'o', label='pruned-tuned', color='green',linewidth=3)
plt.legend()
plt.show()

plt.savefig('prunedvstuned.pdf')

# %%
177.83
import matplotlib.pyplot as plt
import numpy as np

xpruned = np.array([0, 0.0625, 0.125, 0.1875, 0.25, 0.50 ])
ypruned = np.array([177.83, 166.72, 155.60, 144.49,  133.38,  88.92])


plt.xlabel("Channel prune amount (%)")
plt.ylabel("Memory usage (MB)")
plt.title("Memory usage during forward pass against prune amount on the resnet-50 model.")
plt.grid(axis = 'y')
plt.plot(xpruned, ypruned, marker = 's', label='pruned', color='red')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpruned = np.array([0, 0.0625, 0.125, 0.1875, 0.25, 0.50 ])
ypruned = np.array([4.09, 3.60, 3.14, 2.72, 2.32, 1.05])


plt.xlabel("Channel prune amount (%)")
plt.ylabel("MACs (G)")
plt.title("Multiply-adds count against pruning amount on the resnet-50 model.")
plt.grid(axis = 'y')
plt.plot(xpruned, ypruned, marker = 's', label='pruned', color='red')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


x = np.array([69.75, 53.719, 39.065, 12.522])
y = np.array([4.09, 3.60, 3.14, 2.32])
x2 = np.array([69.75, 30.405, 5.702])
y2 = np.array([4.09, 3.60, 3.14])


plt.ylabel("Top-1 Validation accuracy (%)")
plt.xlabel("MACs (G)")
plt.title("Multiply-adds count against validation accuracy on the resnet-50 model.")
plt.grid(axis = 'y')
plt.plot(y2, x2,  marker = 's', label='pruned', color='green')
plt.plot(y, x, marker = 's', label='pruned-tuned', color='red')

plt.legend()
plt.show()
